# %% [markdown]
# <a href="https://colab.research.google.com/github/AxelMoroz/AxelMoroz/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
|

# %% [markdown]
# [google](https://google.com)

# %%
# Programa que pide un número y dice si es par o impar

# Pedimos un número al usuario
numero = int(input("Ingrese un número: "))

# Verificamos si es par o impar
if numero % 2 == 0:
    print(f"El número {numero} es par.")
else:
    print(f"El número {numero} es impar.")
# Out:
# Ingrese un número: 1
# El número 1 es impar.

# %% [markdown]
# ![kisspng-plato-ancient-greece-phaedo-republic-allegory-of-t-grece-5b151d41633d95.2461809415281104014065.png](data:image/png;base64,...)
